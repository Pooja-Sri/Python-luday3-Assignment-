# %%
n=8
sum=0
i=1
while i<=n:
    sum=sum+i
    print (i,"==》",sum)
    i=i+1
print ("Sum=",sum)
# Out:
# 1 ==》 1
# 2 ==》 3
# 3 ==》 6
# 4 ==》 10
# 5 ==》 15
# 6 ==》 21
# 7 ==》 28
# 8 ==》 36
# Sum= 36

# %%
n=13
if n>1:
  for i in range (2,n):
    if (n%i)==0:
      print (n,"is NOT a prime number")
      break
  else:
      print (n,"is PRIME NUMBER")
else:
   print (n,"is NOT a prime number")
# Out:
# 13 is PRIME NUMBER
